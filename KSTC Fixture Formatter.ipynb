# %%
import pandas as pd

# %%
data = pd.read_csv('./KSTC Winter 2022-23 Fixtures.csv')
data.head()
# Out:
#                    Date  Year    Time Venue       Region     Competition  \
# 0   Saturday, 1 October  2022  1:00pm  Home  Oxfordshire  Ladies Doubles
# 1   Saturday, 8 October  2022  1:00pm  Away  Oxfordshire    Mens Doubles
# 2     Sunday, 9 October  2022  1:00pm  Away  Oxfordshire  Ladies Doubles
# 3    Sunday, 16 October  2022  1:00pm  Home  Oxfordshire  Ladies Doubles
# 4  Saturday, 22 October  2022  1:00pm  Home  Oxfordshire  Ladies Doubles
#
#      Division            Home                Away                  Captain  \
# 0  Division 3  Kings Sutton A  Banbury West End A  Sally McAllister-Little
# 1  Division 4   Oxford City B      Kings Sutton A       Callum Fairbrother
# 2  Division 3     Wychwoods B      Kings Sutton A  Sally McAllister-Little
# 3  Division 6  Kings Sutton B         Woodstock D           Belinda Archer
# 4  Division 3  Kings Sutton A         Haddenham A  Sally McAllister-Little
#
#   Notes
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
output = ""
for i in range(0, len(data)):
    if(data.iloc[i,3] == "Home"):
        venue = "Home Match"
        ks = 6
        opp = 7
    elif(data.iloc[i,3] == "Home Bicester"):
        venue = "Home Match (at Bicester)"
        ks = 6
        opp = 7
    elif(data.iloc[i,3] == "Home Deddington"):
        venue = "Home Match (at Deddington)"
        ks = 6
        opp = 7
    else:
        venue = "Away Match"
        ks = 7
        opp = 6
     
    date = data.iloc[i,0].split()
    
    if((date[1] == "1") or (date[1] == "21") or (date[1] == "31")): 
        sup = "st"
    elif((date[1] == "3") or (date[1] == "23")):
        sup = "rd"
    elif((date[1] == "2") or (date[1] == "22")):
        sup = "nd"
    else:
        sup = "th"

    team = data.iloc[i,5].split()

    output += "<p><strong>" +  date[0] + " " + date[1] + "<sup>" + sup + "</sup> " + date[2] + "</strong> at " + data.iloc[i,2] + " - " + venue + "<br />\n"
    output += data.iloc[i,ks] + " " + team[0] + " vs. " + data.iloc[i,opp] + "<br />\n"
    output += data.iloc[i,4] + " " + data.iloc[i,5] + " " + data.iloc[0,6] + "<br /></p>\n\n"

print(output)
# Out:
# <p><strong>Saturday, 1<sup>st</sup> October</strong> at 1:00pm - Home Match<br />
# Division 3 Ladies vs. Kings Sutton A<br />
# Oxfordshire Ladies Doubles Division 3<br /></p>
#
# <p><strong>Saturday, 8<sup>th</sup> October</strong> at 1:00pm - Away Match<br />
# Oxford City B Mens vs. Division 4<br />
# Oxfordshire Mens Doubles Division 3<br /></p>
#
# <p><strong>Sunday, 9<sup>th</sup> October</strong> at 1:00pm - Away Match<br />
# Wychwoods B Ladies vs. Division 3<br />
# Oxfordshire Ladies Doubles Division 3<br /></p>
#
# <p><strong>Sunday, 16<sup>th</sup> October</strong> at 1:00pm - Home Match<br />
# Division 6 Ladies vs. Kings Sutton B<br />
# Oxfordshire Ladies Doubles Division 3<br /></p>
#
# <p><strong>Saturday, 22<sup>nd</sup> October</strong> at 1:00pm - Home Match<br />
# Division 3 Ladies vs. Kings Sutton A<br />
# Oxfordshire Ladies Doubles Division 3<br /></p>
#
# <p><strong>